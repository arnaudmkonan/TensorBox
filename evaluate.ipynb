# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import json
import subprocess
from scipy.misc import imread
# %matplotlib inline

from train import build_lstm_forward, build_overfeat_forward
from utils import googlenet_load, train_utils
from utils.annolist import AnnotationLib as al
from utils.stitch_wrapper import stitch_rects
from utils.train_utils import add_rectangles

# %%
hypes_file = './hypes/htmls.json'
with open(hypes_file, 'r') as f:
    H = json.load(f)
true_idl = './data/htmls/train.idl'
pred_idl = './output/val_%s.idl' % os.path.basename(hypes_file).replace('.json', '')
true_annos = al.parse(true_idl)

# %%
tf.reset_default_graph()
googlenet = googlenet_load.init(H)
x_in = tf.placeholder(tf.float32, name='x_in')
if H['arch']['use_lstm']:
    pred_boxes, pred_logits, pred_confidences = build_lstm_forward(H, tf.expand_dims(x_in, 0), googlenet, 'test', reuse=None)
else:
    pred_boxes, pred_logits, pred_confidences = build_overfeat_forward(H, tf.expand_dims(x_in, 0), googlenet, 'test')
saver = tf.train.Saver()
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    if H['arch']['use_lstm']:
        saver.restore(sess, 'data/lstm/save.ckpt-320000')
    else:
        saver.restore(sess, 'output/htmls_2016_05_18_01.10/save.ckpt-71000')

    annolist = al.AnnoList()
    for i, true_anno in enumerate(true_annos):
        if i > 500: break
        img = imread('./data/htmls/%s' % true_anno.imageName,mode='RGB')
        feed = {x_in: img}
        (np_pred_boxes, np_pred_confidences) = sess.run([pred_boxes, pred_confidences], feed_dict=feed)
        pred_anno = al.Annotation()
        pred_anno.imageName = true_anno.imageName
        new_img, rects = add_rectangles([img], np_pred_confidences, np_pred_boxes,
                                        H["arch"], use_stitching=True, rnn_len=H['arch']['rnn_len'], min_conf=0.3)
    
        pred_anno.rects = rects
        annolist.append(pred_anno)

        if i % 7 == 0 and i < 50:
            fig = plt.figure(figsize=(12, 12))
            plt.imshow(new_img)
        if i % 100 == 0:
            print(i)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500

# %%
annolist.save(pred_idl)
iou_threshold = 0.5
rpc_cmd = './utils/annolist/doRPC.py --minOverlap %f %s %s' % (iou_threshold, true_idl, pred_idl)
print('$ %s' % rpc_cmd)
rpc_output = subprocess.check_output(rpc_cmd, shell=True)
print(rpc_output)
txt_file = [line for line in rpc_output.split('\n') if line.strip()][-1]
output_png = 'output/results.png'
plot_cmd = './utils/annolist/plotSimple.py %s --output %s' % (txt_file, output_png)
print('$ %s' % plot_cmd)
plot_output = subprocess.check_output(plot_cmd, shell=True)
from IPython.display import Image
Image(filename=output_png)
# Out:
# saving:  ./output/val_htmls.idl
# $ ./utils/annolist/doRPC.py --minOverlap 0.500000 ./data/htmls/train.idl ./output/val_htmls.idl
# Minimum width: 0 height: 0
# Asorting too large/ too small detections
# minWidth: 0
# minHeight: 0
# maxWidth:  inf
# maxHeight:  inf
# #Annotations: 1128
# Setting up graphs ...
# No annotation/detection pair found for: scaled/798.png frame: -1
# No annotation/detection pair found for: scaled/822.png frame: -1
# No annotation/detection pair found for: scaled/379.png frame: -1
# No annotation/detection pair found for: scaled/399.png frame: -1
# No annotation/detection pair found for: scaled/926.png frame: -1
# No annotation/detection pair found for: scaled/666.png frame: -1
# No annotation/detection pair found for: scaled/366.png frame: -1
# No annotation/detection pair found for: scaled/549.png frame: -1
# No annotation/detection pair found for: scaled/986.png frame: -1
# No annotation/detection pair found for: scaled/913.png frame: -1
# No annotation/detection pair found for: scaled/538.png frame: -1
# No annotation/detection pair found for: scaled/888.png frame: -1
# No annotation/detection pair found for: scaled/982.png frame: -1
# No annotation/detection pair found for: scaled/162.png frame: -1
# No annotation/detection pair found for: scaled/641.png frame: -1
# No annotation/detection pair found for: scaled/875.png frame: -1
# No annotation/detection pair found for: scaled/804.png frame: -1
# No annotation/detection pair found for: scaled/923.png frame: -1
# No annotation/detection pair found for: scaled/427.png frame: -1
# No annotation/detection pair found for: scaled/60.png frame: -1
# No annotation/detection pair found for: scaled/294.png frame: -1
# No annotation/detection pair found for: scaled/131.png frame: -1
# No annotation/detection pair found for: scaled/779.png frame: -1
# No annotation/detection pair found for: scaled/447.png frame: -1
# No annotation/detection pair found for: scaled/424.png frame: -1
# No annotation/detection pair found for: scaled/50.png frame: -1
# No annotation/detection pair found for: scaled/245.png frame: -1
# No annotation/detection pair found for: scaled/777.png frame: -1
# No annotation/detection pair found for: scaled/310.png frame: -1
# No annotation/detection pair found for: scaled/857.png frame: -1
# No annotation/detection pair found for: scaled/107.png frame: -1
# No annotation/detection pair found for: scaled/262.png frame: -1
# No annotation/detection pair found for: scaled/946.png frame: -1
# No annotation/detection pair found for: scaled/151.png frame: -1
# No annotation/detection pair found for: scaled/693.png frame: -1
# No annotation/detection pair found for: scaled/957.png frame: -1
# No annotation/detection pair found for: scaled/510.png frame: -1
# No annotation/detection pair found for: scaled/853.png frame: -1
# No annotation/detection pair found for: scaled/58.png frame: -1
# No annotation/detection pair found for: scaled/230.png frame: -1
# No annotation/detection pair found for: scaled/437.png frame: -1
# No annotation/detection pair found for: scaled/976.png frame: -1
# No annotation/detection pair found for: scaled/851.png frame: -1
# No annotation/detection pair found for: scaled/82.png frame: -1
# No annotation/detection pair found for: scaled/927.png frame: -1
# No annotation/detection pair found for: scaled/320.png frame: -1
# No annotation/detection pair found for: scaled/577.png frame: -1
# No annotation/detection pair found for: scaled/702.png frame: -1
# No annotation/detection pair found for: scaled/947.png frame: -1
# No annotation/detection pair found for: scaled/316.png frame: -1
# No annotation/detection pair found for: scaled/719.png frame: -1
# No annotation/detection pair found for: scaled/324.png frame: -1
# No annotation/detection pair found for: scaled/712.png frame: -1
# No annotation/detection pair found for: scaled/529.png frame: -1
# No annotation/detection pair found for: scaled/824.png frame: -1
# No annotation/detection pair found for: scaled/610.png frame: -1
# No annotation/detection pair found for: scaled/472.png frame: -1
# No annotation/detection pair found for: scaled/89.png frame: -1
# No annotation/detection pair found for: scaled/331.png frame: -1
# No annotation/detection pair found for: scaled/392.png frame: -1
# No annotation/detection pair found for: scaled/536.png frame: -1
# No annotation/detection pair found for: scaled/519.png frame: -1
# No annotation/detection pair found for: scaled/411.png frame: -1
# No annotation/detection pair found for: scaled/909.png frame: -1
# No annotation/detection pair found for: scaled/6.png frame: -1
# No annotation/detection pair found for: scaled/63.png frame: -1
# No annotation/detection pair found for: scaled/167.png frame: -1
# No annotation/detection pair found for: scaled/68.png frame: -1
# No annotation/detection pair found for: scaled/962.png frame: -1
# No annotation/detection pair found for: scaled/540.png frame: -1
# No annotation/detection pair found for: scaled/553.png frame: -1
# No annotation/detection pair found for: scaled/613.png frame: -1
# No annotation/detection pair found for: scaled/103.png frame: -1
# No annotation/detection pair found for: scaled/585.png frame: -1
# No annotation/detection pair found for: scaled/348.png frame: -1
# No annotation/detection pair found for: scaled/840.png frame: -1
# No annotation/detection pair found for: scaled/205.png frame: -1
# No annotation/detection pair found for: scaled/600.png frame: -1
# No annotation/detection pair found for: scaled/215.png frame: -1
# No annotation/detection pair found for: scaled/231.png frame: -1
# No annotation/detection pair found for: scaled/669.png frame: -1
# No annotation/detection pair found for: scaled/87.png frame: -1
# No annotation/detection pair found for: scaled/191.png frame: -1
# No annotation/detection pair found for: scaled/597.png frame: -1
# No annotation/detection pair found for: scaled/611.png frame: -1
# No annotation/detection pair found for: scaled/61.png frame: -1
# No annotation/detection pair found for: scaled/94.png frame: -1
# No annotation/detection pair found for: scaled/622.png frame: -1
# No annotation/detection pair found for: scaled/8.png frame: -1
# No annotation/detection pair found for: scaled/664.png frame: -1
# No annotation/detection pair found for: scaled/934.png frame: -1
# No annotation/detection pair found for: scaled/601.png frame: -1
# No annotation/detection pair found for: scaled/917.png frame: -1
# No annotation/detection pair found for: scaled/17.png frame: -1
# No annotation/detection pair found for: scaled/758.png frame: -1
# No annotation/detection pair found for: scaled/575.png frame: -1
# No annotation/detection pair found for: scaled/507.png frame: -1
# No annotation/detection pair found for: scaled/768.png frame: -1
# No annotation/detection pair found for: scaled/953.png frame: -1
# No annotation/detection pair found for: scaled/23.png frame: -1
# No annotation/detection pair found for: scaled/127.png frame: -1
# No annotation/detection pair found for: scaled/993.png frame: -1
# No annotation/detection pair found for: scaled/722.png frame: -1
# No annotation/detection pair found for: scaled/138.png frame: -1
# No annotation/detection pair found for: scaled/650.png frame: -1
# No annotation/detection pair found for: scaled/884.png frame: -1
# No annotation/detection pair found for: scaled/346.png frame: -1
# No annotation/detection pair found for: scaled/674.png frame: -1
# No annotation/detection pair found for: scaled/695.png frame: -1
# No annotation/detection pair found for: scaled/443.png frame: -1
# No annotation/detection pair found for: scaled/0.png frame: -1
# No annotation/detection pair found for: scaled/109.png frame: -1
# No annotation/detection pair found for: scaled/915.png frame: -1
# No annotation/detection pair found for: scaled/945.png frame: -1
# No annotation/detection pair found for: scaled/520.png frame: -1
# No annotation/detection pair found for: scaled/54.png frame: -1
# No annotation/detection pair found for: scaled/753.png frame: -1
# No annotation/detection pair found for: scaled/891.png frame: -1
# No annotation/detection pair found for: scaled/209.png frame: -1
# No annotation/detection pair found for: scaled/444.png frame: -1
# No annotation/detection pair found for: scaled/654.png frame: -1
# No annotation/detection pair found for: scaled/258.png frame: -1
# No annotation/detection pair found for: scaled/198.png frame: -1
# No annotation/detection pair found for: scaled/492.png frame: -1
# No annotation/detection pair found for: scaled/3.png frame: -1
# No annotation/detection pair found for: scaled/322.png frame: -1
# No annotation/detection pair found for: scaled/879.png frame: -1
# No annotation/detection pair found for: scaled/297.png frame: -1
# No annotation/detection pair found for: scaled/20.png frame: -1
# No annotation/detection pair found for: scaled/96.png frame: -1
# No annotation/detection pair found for: scaled/377.png frame: -1
# No annotation/detection pair found for: scaled/738.png frame: -1
# No annotation/detection pair found for: scaled/475.png frame: -1
# No annotation/detection pair found for: scaled/371.png frame: -1
# No annotation/detection pair found for: scaled/867.png frame: -1
# No annotation/detection pair found for: scaled/895.png frame: -1
# No annotation/detection pair found for: scaled/225.png frame: -1
# No annotation/detection pair found for: scaled/75.png frame: -1
# No annotation/detection pair found for: scaled/810.png frame: -1
# No annotation/detection pair found for: scaled/117.png frame: -1
# No annotation/detection pair found for: scaled/372.png frame: -1
# No annotation/detection pair found for: scaled/985.png frame: -1
# No annotation/detection pair found for: scaled/544.png frame: -1
# No annotation/detection pair found for: scaled/846.png frame: -1
# No annotation/detection pair found for: scaled/98.png frame: -1
# No annotation/detection pair found for: scaled/880.png frame: -1
# No annotation/detection pair found for: scaled/566.png frame: -1
# No annotation/detection pair found for: scaled/951.png frame: -1
# No annotation/detection pair found for: scaled/344.png frame: -1
# No annotation/detection pair found for: scaled/678.png frame: -1
# No annotation/detection pair found for: scaled/459.png frame: -1
# No annotation/detection pair found for: scaled/636.png frame: -1
# No annotation/detection pair found for: scaled/257.png frame: -1
# No annotation/detection pair found for: scaled/683.png frame: -1
# No annotation/detection pair found for: scaled/177.png frame: -1
# No annotation/detection pair found for: scaled/259.png frame: -1
# No annotation/detection pair found for: scaled/490.png frame: -1
# No annotation/detection pair found for: scaled/302.png frame: -1
# No annotation/detection pair found for: scaled/471.png frame: -1
# No annotation/detection pair found for: scaled/47.png frame: -1
# No annotation/detection pair found for: scaled/216.png frame: -1
# No annotation/detection pair found for: scaled/287.png frame: -1
# No annotation/detection pair found for: scaled/200.png frame: -1
# No annotation/detection pair found for: scaled/356.png frame: -1
# No annotation/detection pair found for: scaled/19.png frame: -1
# No annotation/detection pair found for: scaled/630.png frame: -1
# No annotation/detection pair found for: scaled/108.png frame: -1
# No annotation/detection pair found for: scaled/484.png frame: -1
# No annotation/detection pair found for: scaled/449.png frame: -1
# No annotation/detection pair found for: scaled/609.png frame: -1
# No annotation/detection pair found for: scaled/619.png frame: -1
# No annotation/detection pair found for: scaled/398.png frame: -1
# No annotation/detection pair found for: scaled/266.png frame: -1
# No annotation/detection pair found for: scaled/458.png frame: -1
# No annotation/detection pair found for: scaled/871.png frame: -1
# No annotation/detection pair found for: scaled/699.png frame: -1
# No annotation/detection pair found for: scaled/367.png frame: -1
# No annotation/detection pair found for: scaled/496.png frame: -1
# No annotation/detection pair found for: scaled/989.png frame: -1
# No annotation/detection pair found for: scaled/972.png frame: -1
# No annotation/detection pair found for: scaled/457.png frame: -1
# No annotation/detection pair found for: scaled/859.png frame: -1
# No annotation/detection pair found for: scaled/576.png frame: -1
# No annotation/detection pair found for: scaled/285.png frame: -1
# No annotation/detection pair found for: scaled/78.png frame: -1
# No annotation/detection pair found for: scaled/521.png frame: -1
# No annotation/detection pair found for: scaled/752.png frame: -1
# No annotation/detection pair found for: scaled/775.png frame: -1
# No annotation/detection pair found for: scaled/301.png frame: -1
# No annotation/detection pair found for: scaled/854.png frame: -1
# No annotation/detection pair found for: scaled/858.png frame: -1
# No annotation/detection pair found for: scaled/749.png frame: -1
# No annotation/detection pair found for: scaled/863.png frame: -1
# No annotation/detection pair found for: scaled/983.png frame: -1
# No annotation/detection pair found for: scaled/279.png frame: -1
# No annotation/detection pair found for: scaled/140.png frame: -1
# No annotation/detection pair found for: scaled/222.png frame: -1
# No annotation/detection pair found for: scaled/71.png frame: -1
# No annotation/detection pair found for: scaled/605.png frame: -1
# No annotation/detection pair found for: scaled/100.png frame: -1
# No annotation/detection pair found for: scaled/277.png frame: -1
# No annotation/detection pair found for: scaled/4.png frame: -1
# No annotation/detection pair found for: scaled/911.png frame: -1
# No annotation/detection pair found for: scaled/625.png frame: -1
# No annotation/detection pair found for: scaled/369.png frame: -1
# No annotation/detection pair found for: scaled/252.png frame: -1
# No annotation/detection pair found for: scaled/237.png frame: -1
# No annotation/detection pair found for: scaled/820.png frame: -1
# No annotation/detection pair found for: scaled/343.png frame: -1
# No annotation/detection pair found for: scaled/360.png frame: -1
# No annotation/detection pair found for: scaled/364.png frame: -1
# No annotation/detection pair found for: scaled/561.png frame: -1
# No annotation/detection pair found for: scaled/462.png frame: -1
# No annotation/detection pair found for: scaled/439.png frame: -1
# No annotation/detection pair found for: scaled/805.png frame: -1
# No annotation/detection pair found for: scaled/37.png frame: -1
# No annotation/detection pair found for: scaled/935.png frame: -1
# No annotation/detection pair found for: scaled/552.png frame: -1
# No annotation/detection pair found for: scaled/116.png frame: -1
# No annotation/detection pair found for: scaled/189.png frame: -1
# No annotation/detection pair found for: scaled/249.png frame: -1
# No annotation/detection pair found for: scaled/438.png frame: -1
# No annotation/detection pair found for: scaled/772.png frame: -1
# No annotation/detection pair found for: scaled/928.png frame: -1
# No annotation/detection pair found for: scaled/963.png frame: -1
# No annotation/detection pair found for: scaled/174.png frame: -1
# No annotation/detection pair found for: scaled/557.png frame: -1
# No annotation/detection pair found for: scaled/423.png frame: -1
# No annotation/detection pair found for: scaled/192.png frame: -1
# No annotation/detection pair found for: scaled/74.png frame: -1
# No annotation/detection pair found for: scaled/164.png frame: -1
# No annotation/detection pair found for: scaled/825.png frame: -1
# No annotation/detection pair found for: scaled/628.png frame: -1
# No annotation/detection pair found for: scaled/243.png frame: -1
# No annotation/detection pair found for: scaled/309.png frame: -1
# No annotation/detection pair found for: scaled/296.png frame: -1
# No annotation/detection pair found for: scaled/483.png frame: -1
# No annotation/detection pair found for: scaled/489.png frame: -1
# No annotation/detection pair found for: scaled/158.png frame: -1
# No annotation/detection pair found for: scaled/272.png frame: -1
# No annotation/detection pair found for: scaled/721.png frame: -1
# No annotation/detection pair found for: scaled/981.png frame: -1
# No annotation/detection pair found for: scaled/532.png frame: -1
# No annotation/detection pair found for: scaled/179.png frame: -1
# No annotation/detection pair found for: scaled/656.png frame: -1
# No annotation/detection pair found for: scaled/751.png frame: -1
# No annotation/detection pair found for: scaled/602.png frame: -1
# No annotation/detection pair found for: scaled/226.png frame: -1
# No annotation/detection pair found for: scaled/646.png frame: -1
# No annotation/detection pair found for: scaled/488.png frame: -1
# No annotation/detection pair found for: scaled/984.png frame: -1
# No annotation/detection pair found for: scaled/491.png frame: -1
# No annotation/detection pair found for: scaled/608.png frame: -1
# No annotation/detection pair found for: scaled/907.png frame: -1
# No annotation/detection pair found for: scaled/156.png frame: -1
# No annotation/detection pair found for: scaled/864.png frame: -1
# No annotation/detection pair found for: scaled/111.png frame: -1
# No annotation/detection pair found for: scaled/40.png frame: -1
# No annotation/detection pair found for: scaled/517.png frame: -1
# No annotation/detection pair found for: scaled/528.png frame: -1
# No annotation/detection pair found for: scaled/769.png frame: -1
# No annotation/detection pair found for: scaled/583.png frame: -1
# No annotation/detection pair found for: scaled/546.png frame: -1
# No annotation/detection pair found for: scaled/308.png frame: -1
# No annotation/detection pair found for: scaled/333.png frame: -1
# No annotation/detection pair found for: scaled/812.png frame: -1
# No annotation/detection pair found for: scaled/173.png frame: -1
# No annotation/detection pair found for: scaled/425.png frame: -1
# No annotation/detection pair found for: scaled/391.png frame: -1
# No annotation/detection pair found for: scaled/13.png frame: -1
# No annotation/detection pair found for: scaled/160.png frame: -1
# No annotation/detection pair found for: scaled/481.png frame: -1
# No annotation/detection pair found for: scaled/711.png frame: -1
# No annotation/detection pair found for: scaled/97.png frame: -1
# No annotation/detection pair found for: scaled/91.png frame: -1
# No annotation/detection pair found for: scaled/868.png frame: -1
# No annotation/detection pair found for: scaled/402.png frame: -1
# No annotation/detection pair found for: scaled/197.png frame: -1
# No annotation/detection pair found for: scaled/590.png frame: -1
# No annotation/detection pair found for: scaled/143.png frame: -1
# No annotation/detection pair found for: scaled/655.png frame: -1
# No annotation/detection pair found for: scaled/860.png frame: -1
# No annotation/detection pair found for: scaled/505.png frame: -1
# No annotation/detection pair found for: scaled/53.png frame: -1
# No annotation/detection pair found for: scaled/124.png frame: -1
# No annotation/detection pair found for: scaled/743.png frame: -1
# No annotation/detection pair found for: scaled/623.png frame: -1
# No annotation/detection pair found for: scaled/704.png frame: -1
# No annotation/detection pair found for: scaled/396.png frame: -1
# No annotation/detection pair found for: scaled/881.png frame: -1
# No annotation/detection pair found for: scaled/809.png frame: -1
# No annotation/detection pair found for: scaled/562.png frame: -1
# No annotation/detection pair found for: scaled/339.png frame: -1
# No annotation/detection pair found for: scaled/436.png frame: -1
# No annotation/detection pair found for: scaled/662.png frame: -1
# No annotation/detection pair found for: scaled/321.png frame: -1
# No annotation/detection pair found for: scaled/797.png frame: -1
# No annotation/detection pair found for: scaled/76.png frame: -1
# No annotation/detection pair found for: scaled/740.png frame: -1
# No annotation/detection pair found for: scaled/692.png frame: -1
# No annotation/detection pair found for: scaled/380.png frame: -1
# No annotation/detection pair found for: scaled/694.png frame: -1
# No annotation/detection pair found for: scaled/882.png frame: -1
# No annotation/detection pair found for: scaled/689.png frame: -1
# No annotation/detection pair found for: scaled/659.png frame: -1
# No annotation/detection pair found for: scaled/51.png frame: -1
# No annotation/detection pair found for: scaled/651.png frame: -1
# No annotation/detection pair found for: scaled/134.png frame: -1
# No annotation/detection pair found for: scaled/950.png frame: -1
# No annotation/detection pair found for: scaled/530.png frame: -1
# No annotation/detection pair found for: scaled/1.png frame: -1
# No annotation/detection pair found for: scaled/337.png frame: -1
# No annotation/detection pair found for: scaled/363.png frame: -1
# No annotation/detection pair found for: scaled/409.png frame: -1
# No annotation/detection pair found for: scaled/764.png frame: -1
# No annotation/detection pair found for: scaled/670.png frame: -1
# No annotation/detection pair found for: scaled/317.png frame: -1
# No annotation/detection pair found for: scaled/44.png frame: -1
# No annotation/detection pair found for: scaled/748.png frame: -1
# No annotation/detection pair found for: scaled/803.png frame: -1
# No annotation/detection pair found for: scaled/799.png frame: -1
# No annotation/detection pair found for: scaled/355.png frame: -1
# No annotation/detection pair found for: scaled/587.png frame: -1
# No annotation/detection pair found for: scaled/739.png frame: -1
# No annotation/detection pair found for: scaled/932.png frame: -1
# No annotation/detection pair found for: scaled/773.png frame: -1
# No annotation/detection pair found for: scaled/707.png frame: -1
# No annotation/detection pair found for: scaled/56.png frame: -1
# No annotation/detection pair found for: scaled/478.png frame: -1
# No annotation/detection pair found for: scaled/526.png frame: -1
# No annotation/detection pair found for: scaled/482.png frame: -1
# No annotation/detection pair found for: scaled/313.png frame: -1
# No annotation/detection pair found for: scaled/789.png frame: -1
# No annotation/detection pair found for: scaled/581.png frame: -1
# No annotation/detection pair found for: scaled/388.png frame: -1
# No annotation/detection pair found for: scaled/129.png frame: -1
# No annotation/detection pair found for: scaled/299.png frame: -1
# No annotation/detection pair found for: scaled/214.png frame: -1
# No annotation/detection pair found for: scaled/79.png frame: -1
# No annotation/detection pair found for: scaled/35.png frame: -1
# No annotation/detection pair found for: scaled/314.png frame: -1
# No annotation/detection pair found for: scaled/153.png frame: -1
# No annotation/detection pair found for: scaled/220.png frame: -1
# No annotation/detection pair found for: scaled/92.png frame: -1
# No annotation/detection pair found for: scaled/474.png frame: -1
# No annotation/detection pair found for: scaled/762.png frame: -1
# No annotation/detection pair found for: scaled/470.png frame: -1
# No annotation/detection pair found for: scaled/362.png frame: -1
# No annotation/detection pair found for: scaled/2.png frame: -1
# No annotation/detection pair found for: scaled/826.png frame: -1
# No annotation/detection pair found for: scaled/829.png frame: -1
# No annotation/detection pair found for: scaled/594.png frame: -1
# No annotation/detection pair found for: scaled/894.png frame: -1
# No annotation/detection pair found for: scaled/615.png frame: -1
# No annotation/detection pair found for: scaled/992.png frame: -1
# No annotation/detection pair found for: scaled/141.png frame: -1
# No annotation/detection pair found for: scaled/422.png frame: -1
# No annotation/detection pair found for: scaled/869.png frame: -1
# No annotation/detection pair found for: scaled/652.png frame: -1
# No annotation/detection pair found for: scaled/574.png frame: -1
# No annotation/detection pair found for: scaled/618.png frame: -1
# No annotation/detection pair found for: scaled/105.png frame: -1
# No annotation/detection pair found for: scaled/551.png frame: -1
# No annotation/detection pair found for: scaled/965.png frame: -1
# No annotation/detection pair found for: scaled/929.png frame: -1
# No annotation/detection pair found for: scaled/560.png frame: -1
# No annotation/detection pair found for: scaled/59.png frame: -1
# No annotation/detection pair found for: scaled/522.png frame: -1
# No annotation/detection pair found for: scaled/227.png frame: -1
# No annotation/detection pair found for: scaled/194.png frame: -1
# No annotation/detection pair found for: scaled/788.png frame: -1
# No annotation/detection pair found for: scaled/426.png frame: -1
# No annotation/detection pair found for: scaled/397.png frame: -1
# No annotation/detection pair found for: scaled/643.png frame: -1
# No annotation/detection pair found for: scaled/295.png frame: -1
# No annotation/detection pair found for: scaled/42.png frame: -1
# No annotation/detection pair found for: scaled/735.png frame: -1
# No annotation/detection pair found for: scaled/228.png frame: -1
# No annotation/detection pair found for: scaled/115.png frame: -1
# No annotation/detection pair found for: scaled/353.png frame: -1
# No annotation/detection pair found for: scaled/165.png frame: -1
# No annotation/detection pair found for: scaled/464.png frame: -1
# No annotation/detection pair found for: scaled/705.png frame: -1
# No annotation/detection pair found for: scaled/328.png frame: -1
# No annotation/detection pair found for: scaled/661.png frame: -1
# No annotation/detection pair found for: scaled/603.png frame: -1
# No annotation/detection pair found for: scaled/428.png frame: -1
# No annotation/detection pair found for: scaled/473.png frame: -1
# No annotation/detection pair found for: scaled/791.png frame: -1
# No annotation/detection pair found for: scaled/629.png frame: -1
# No annotation/detection pair found for: scaled/219.png frame: -1
# No annotation/detection pair found for: scaled/535.png frame: -1
# No annotation/detection pair found for: scaled/887.png frame: -1
# No annotation/detection pair found for: scaled/845.png frame: -1
# No annotation/detection pair found for: scaled/142.png frame: -1
# No annotation/detection pair found for: scaled/223.png frame: -1
# No annotation/detection pair found for: scaled/479.png frame: -1
# No annotation/detection pair found for: scaled/211.png frame: -1
# No annotation/detection pair found for: scaled/697.png frame: -1
# missingFrames:  399
# Number of detections on annotated frames:  911
# Sorting scores ...
# Gradually decrease score ...
# saving:
# /home/xiao/workspace/tensorbox/output/rpc-val_htmls_overlap0.5.txt
#
# $ ./utils/annolist/plotSimple.py /home/xiao/workspace/tensorbox/output/rpc-val_htmls_overlap0.5.txt --output output/results.png
